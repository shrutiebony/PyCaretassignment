# %% [markdown]
# ### Uncomment the below lines to install dependecies if depencies not already installed

# %%
# !pip install pycaret
# !pip install pycaret gradio

# %% [markdown]
# ### All imports

# %%
import pycaret
import gradio as gr
from pycaret.regression import *

# %% [markdown]
# ### Get the data and the initial setup

# %%
from pycaret.datasets import get_data
diamond_data = get_data('diamond')
initial_setup = setup(diamond_data, target = 'Price')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171
# <style type="text/css">
# #T_cc46f_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cc46f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc46f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cc46f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc46f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc46f_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# ### Model and the app creation

# %%
create_model_var = create_model('dt')
create_app(create_model_var)
# Out:
# <style type="text/css">
# #T_03a48_row10_col0, #T_03a48_row10_col1, #T_03a48_row10_col2, #T_03a48_row10_col3, #T_03a48_row10_col4, #T_03a48_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_03a48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03a48_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_03a48_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_03a48_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_03a48_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_03a48_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_03a48_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
